# %%
import requests
import json
import pandas as pd
import seaborn as sns
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
net_gen_all_df = pd.read_csv('../DA17_Capstone/data/Net_generation_for_all_sectors.csv')
net_gen_all_df.head()
# Out:
#                                  description                   units  \
# 0             Net generation for all sectors  thousand megawatthours
# 1                              United States                     NaN
# 2  United States : all fuels (utility-scale)  thousand megawatthours
# 3                       United States : coal  thousand megawatthours
# 4          United States : petroleum liquids  thousand megawatthours
#
#              source key     2001     2002     2003     2004     2005     2006  \
# 0                   NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1           ELEC.GEN..A      NaN      NaN      NaN      NaN      NaN      NaN
# 2  ELEC.GEN.ALL-US-99.A  3736644  3858452  3883185  3970555  4055423  4064702
# 3  ELEC.GEN.COW-US-99.A  1903956  1933130  1973737  1978301  2012873  1990511
# 4  ELEC.GEN.PEL-US-99.A   114647    78701   102734   100391    99840    44460
#
#       2007  ...     2016     2017     2018     2019     2020     2021  \
# ...

# %% [markdown]
# ## Bring in Consumption Data When Needed

# %% [markdown]
# tot_consumption_all_df = pd.read_csv('../DA17_Capstone/data/Total_consumption_(Btu)_for_all_sectors.csv')
# tot_consumption_all_df.head()

# %% [markdown]
# new_col2 = tot_consumption_all_df['description'].str.split(':', n=1, expand=True)
# tot_consumption_all_df['location'] = new_col[0]
# tot_consumption_all_df['fuel'] = new_col[1]

# %% [markdown]
# tot_consumption_all_df = tot_consumption_all_df.fillna(0)

# %% [markdown]
# tot_consumption_all_df.head()

# %% [markdown]
# ## Clean Net Gen Data

# %%
# splitting description column into two separate columns, location and fuel
new_col = net_gen_all_df['description'].str.split(':', n=1, expand=True)
net_gen_all_df['location'] = new_col[0]
net_gen_all_df['fuel'] = new_col[1]

# %%
# removing NaN with 0
net_gen_all_df = net_gen_all_df.fillna(0)

# %%
net_gen_all_df['location'].unique()
# Out:
# array(['Net generation for all sectors', 'United States',
#        'United States ', 'New England', 'New England ', 'Connecticut',
#        'Connecticut ', 'Maine', 'Maine ', 'Massachusetts',
#        'Massachusetts ', 'New Hampshire', 'New Hampshire ',
#        'Rhode Island', 'Rhode Island ', 'Vermont', 'Vermont ',
#        'Middle Atlantic', 'Middle Atlantic ', 'New Jersey', 'New Jersey ',
#        'New York', 'New York ', 'Pennsylvania', 'Pennsylvania ',
#        'East North Central', 'East North Central ', 'Illinois',
#        'Illinois ', 'Indiana', 'Indiana ', 'Michigan', 'Michigan ',
#        'Ohio', 'Ohio ', 'Wisconsin', 'Wisconsin ', 'West North Central',
#        'West North Central ', 'Iowa', 'Iowa ', 'Kansas', 'Kansas ',
#        'Minnesota', 'Minnesota ', 'Missouri', 'Missouri ', 'Nebraska',
#        'Nebraska ', 'North Dakota', 'North Dakota ', 'South Dakota',
#        'South Dakota ', 'South Atlantic', 'South Atlantic ', 'Delaware',
# ...
